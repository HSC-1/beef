# %%
import os
import glob
base_path = os.getenv('HOME') + '/beef/'
img_path = base_path + 'Prime_zoo/*'
# img_path
img_list = glob.glob(img_path) 
img_list
# Out:
# ['/home/aiffel-dj26/beef/Prime_zoo/Screenshot from 2021-05-13 13-44-55.png',
#  '/home/aiffel-dj26/beef/Prime_zoo/Screenshot from 2021-05-13 14-04-35(1).png',
#  '/home/aiffel-dj26/beef/Prime_zoo/Screenshot from 2021-05-13 13-13-02.png',
#  '/home/aiffel-dj26/beef/Prime_zoo/Screenshot from 2021-05-13 12-01-19.png',
#  '/home/aiffel-dj26/beef/Prime_zoo/Screenshot from 2021-05-13 14-29-53.png',
#  '/home/aiffel-dj26/beef/Prime_zoo/Screenshot from 2021-05-13 11-53-55.png',
#  '/home/aiffel-dj26/beef/Prime_zoo/Screenshot from 2021-05-13 11-23-10.png',
#  '/home/aiffel-dj26/beef/Prime_zoo/Screenshot from 2021-05-13 11-29-38.png',
#  '/home/aiffel-dj26/beef/Prime_zoo/Screenshot from 2021-05-13 14-16-20.png',
#  '/home/aiffel-dj26/beef/Prime_zoo/Screenshot from 2021-05-13 14-04-35.png',
#  '/home/aiffel-dj26/beef/Prime_zoo/Screenshot from 2021-05-13 12-01-30.png',
#  '/home/aiffel-dj26/beef/Prime_zoo/Screenshot from 2021-05-13 14-04-47(1).png',
# ...

# %%
import cv2
import matplotlib.pyplot as plt
img_lists = cv2.imread(img_list[0])
plt.imshow(img_lists)
